# %%
# %pip install "ultralytics<=8.3.40" supervision roboflow
# prevent ultralytics from tracking your activity
# !yolo settings sync=False
import ultralytics
ultralytics.checks()
from ultralytics import YOLO

print("YOLOv11 installé !")
# Out:
# Ultralytics 8.3.235 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.6/112.6 GB disk)
# YOLOv11 installé !

# %%
import os
os.environ["DATASET_DIRECTORY"]="/content/datasets"

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

from google.colab import userdata
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="VZO6SmUj0jHFMMCYCy2N")
project = rf.workspace("fire-detection").project("fire-detection-data-pre")
version = project.version(4)
dataset = version.download("yolov11")
# Out:
# mkdir: cannot create directory ‘{HOME}/datasets’: No such file or directory
# [Errno 2] No such file or directory: '{HOME}/datasets'
# /content
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to /content/datasets/fire-detection-data-pre-4 in yolov11:: 100%|██████████| 4012/4012 [00:00<00:00, 10357.34it/s]

# %%
# !yolo task=detect mode=train model=yolo11n.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 plots=True
# Out:
# ...
# 100% 5.35M/5.35M [00:00<00:00, 102MB/s]
# New https://pypi.org/project/ultralytics/8.3.235 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
